# %%
'''Consider following code to answer further questions:'''

import pandas as pd

course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']

duration =  [2,3,6,4]

df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
'''Q1. Write a code to print the data present in the second row of the dataframe, df.'''
print(df)
print(df.course_name[1])
print(df.duration[1])

'''Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?'''



'''Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df 
then find the output for both new_df.loc[2] and new_df.iloc[2].'''
#Solve:

print("\n\n")
reindex=[3,0,1,2]
new_df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration},index=reindex)
print(new_df)
print("")
print(new_df.loc[2])
print("")
print(new_df.iloc[2])







import pandas as pd

import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']

indices = [1,2,3,4,5,6]
reindex=[]
#Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)












'''Q4. Write a code to find the following statistical measurements for the above dataframe df1:

(i) 	mean of each and every column present in the dataframe.

(ii) standard deviation of column, ‘column_2’'''

import pandas as pd

import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']

indices = [1,2,3,4,5,6]
reindex=[]
#Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

#Solve(i)
print("\n\nMean of all column.")
print(np.mean(df1))

#Solve(ii)
print("\n\nStandard deviation of column2.")
print(np.std(df1.column_2))




'''Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the 
mean of column, column_2.

If you are getting errors in executing it then explain why.

[Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]'''


'''Q6. What do you understand about the windows function in pandas and list the types of windows 
functions?'''


'''Q7. Write a code to print only the current month and year at the time of answering this question.

[Hint: Use pandas.datetime function]'''


#Solve:
import pandas as pd
print(pd.datetime())


'''Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and 
calculates the difference between them in days, hours, and minutes using Pandas time delta. The 
program should prompt the user to enter the dates and display the result.
Did you observe any difference in both the outputs? If so then explain it.

Consider the below code to answer further questions:
import pandas as pd

import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']

indices = [1,2,3,4,5,6]

#Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices'''


'''Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified 
column to a categorical data type. The program should prompt the user to enter the file path, column 
name, and category order, and then display the sorted data



import pandas as pd

# Prompt the user for the file path
file_path = input("Enter the file path: ")

# Read the CSV file
df = pd.read_csv(file_path)

# Prompt the user for the column name
column_name = input("Enter the column name: ")

# Prompt the user for the category order
category_order = input("Enter the category order (comma-separated): ").split(',')

# Convert the specified column to categorical data type
df[column_name] = pd.Categorical(df[column_name], categories=category_order, ordered=True)

# Sort the data by the categorical column
sorted_df = df.sort_values(column_name)

# Display the sorted data
print(sorted_df)
In this program, the user is prompted to enter the file path of the CSV file, the column name to convert to categorical data type, and the category order. The CSV file is then read using pd.read_csv(). The specified column is converted to a categorical data type using pd.Categorical(), specifying the category order provided by the user.

The data is sorted based on the categorical column using df.sort_values(), and the sorted DataFrame is stored in sorted_df. Finally, the sorted data is displayed using print(sorted_df).

Make sure that the CSV file is in the correct format and the column name and category order provided by the user match the data in the file.

'''


'''Q10. Write a Python program that reads a CSV file containing sales data for different products and 
visualizes the data using a stacked bar chart to show the sales of each product category over time. The 
program should prompt the user to enter the file path and display the chart


import pandas as pd
import matplotlib.pyplot as plt

# Prompt the user for the file path
file_path = input("Enter the file path: ")

# Read the CSV file
df = pd.read_csv(file_path)

# Pivot the data to get the sales of each product category over time
pivot_df = df.pivot(index='Date', columns='Category', values='Sales')

# Plot a stacked bar chart
pivot_df.plot(kind='bar', stacked=True)

# Set the chart title and labels
plt.title('Sales of Product Categories Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')

# Display the chart
plt.show()
In this program, the user is prompted to enter the file path of the CSV file. The CSV file is read using pd.read_csv(), assuming that it contains columns named 'Date', 'Category', and 'Sales' representing the date, product category, and sales respectively.

The data is then pivoted using df.pivot() to get the sales of each product category over time. A stacked bar chart is plotted using pivot_df.plot(kind='bar', stacked=True).

The chart title, x-axis label, and y-axis label are set using plt.title(), plt.xlabel(), and plt.ylabel() respectively. Finally, the chart is displayed using plt.show().

Make sure to have the necessary dependencies installed, such as pandas and matplotlib, before running the program.

'''


'''Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write 
a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and 
displays the results in a table.
The program should do the followingM
I Prompt the user to enter the file path of the CSV file containing the student dataR
I Read the CSV file into a Pandas DataFrameR
I Calculate the mean, median, and mode of the test scores using Pandas toolsR
I Display the mean, median, and mode in a table.

Assume the CSV file contains the following columnsM
I Student ID: The ID of the studentR
I Test Score: The score of the student's test.
Example usage of the program:

Enter the file path of the CSV file containing the student data: student_data.csv


+-----------+--------+

| Statistic | Value  |

+-----------+--------+

| Mean      | 79.6   |

| Median    | 82     |

| Mode      | 85, 90 |

+-----------+--------+


Assume that the CSV file student_data.csv contains the following data:

Student ID,Test Score

1,85

2,90

3,80

4,75

5,85

6,82

7,78

8,85

9,90

10,85


The program should calculate the mean, median, and mode of the test scores and display the results 
in a table.


solve:-

      import pandas as pd

def calculate_statistics(df):
    mean_score = df['Test Score'].mean()
    median_score = df['Test Score'].median()
    mode_scores = df['Test Score'].mode()
    return mean_score, median_score, mode_scores

def display_table(mean, median, modes):
    table = pd.DataFrame({
        'Statistic': ['Mean', 'Median', 'Mode'],
        'Value': [mean, median, ', '.join(map(str, modes))]
    })
    print(table)

def main():
    file_path = input("Enter the file path of the CSV file containing the student data: ")
    df = pd.read_csv(file_path)
    mean, median, modes = calculate_statistics(df)
    display_table(mean, median, modes)

if __name__ == "__main__":
    main()





'''
