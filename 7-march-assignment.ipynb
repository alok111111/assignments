# %%
'''Q1. What are the three measures of central tendency?
Ans:- (i.) Mean(Average)
      (ii.) Median
      (iii.) Mode'''
'''Q2. What is the difference between the mean, median, and mode? How are they used to measure the 
central tendency of a dataset?

Ans:-
Mean:-mean is a very important measures of centeral tendecy find any data set average
Median:-median is a find centeral data in between dataset.But there are two condition 

(i)if dataset is even then choose two central value and add or divide by two then able to calculate median.

(ii.)if dataset is odd then select center value for median.
also finding outliers help by median.

 Mode:- mode is used for find-out frequency(no.of occurences)
this is basic difference between mean,median,mode.

'''

'''Q3. Measure the three measures of central tendency for the given height data:


'''
#Solve:

height= [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]
import numpy as np
import pandas as pd
Mean=np.mean(height)
Median=np.median(height)
##Mode=np.mode(height)
print("Mean of heights= ",Mean)
print("Median of heights= ",Median)
##print("Mode of heights= ",Mode)

'''Q4. Find the standard deviation for the given data:'''
#Solve:
data=[178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

Standard_deviation=np.std(data)
print("Standard-deviation of given data is= ",Standard_deviation)

'''Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe 
the spread of a dataset? Provide an example.'''







'''Q6. What is a Venn diagram?
Ans:-
    Venn diagram is a very important for mathematical represenation  or logical sets
    pictorially as circles or closed curves within an encoding rectangle(th universal set.)


'''

'''Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:

(i) 	A intersection b.

(ii)	A ⋃ B'''

#Solve:

A=(2,3,4,5,6,7)
B=(0,2,6,8,10)
intersection=np.intersect1d(A,B)
union=np.union1d(A,B)
print('Intersection of A and B',intersection)
print('Union of A and B',union)

#(i) A intersection B=(2,6)

#(ii)	A ⋃ B =(0,2,3,4,5,6,7,8,10)

'''Q8. What do you understand about skewness in data?
Ans:- Skewness is a measures of normal distribution.the highest point of distribution is is mode.
the mode marks response value o x-axis that occurs highest probability.
There are many types of skewness.

(a.) Right skewed or positive skewed
(b.) Left  skewed or negative skewed

'''


'''Q9. If a data is right skewed then what will be the position of median with respect to mean?

Ans:-
     mean>=median>=mode in this condition.

'''

'''Q10. Explain the difference between covariance and correlation. How are these measures used in 
statistical analysis?

Ans:-Covariance and correlation is two term to used statisticals and regression.
covariance is show how variable differ but correlation show how variables related to each other
this is main difference.

lets,
   x=1,2,3,4,5
   y=6,7,8,9,10

   in this condition.
relation between x and y.

(i.)if x is increased then y is increased.
(ii.)if x is decreased then y is decreased.
 and then used formula to calculate covariance and correlation.

'''

'''Q11. What is the formula for calculating the sample mean? Provide an example calculation for a 
dataset.

formula: x-bar=sumation(xi/n)
where,
      xi=datapoint
      n=no.of dataset.

'''
data1=np.linspace(1,10,500)
sample_mean=np.mean(data1)
print('sample_mean=',sample_mean)


'''Q12. For a normal distribution data what is the relationship between its measure of central tendency?

Ans:- In Normal or Gausion distribution relationship between is.


Mean>=Median>=mode.

'''

'''Q13. How is covariance different from correlation
 
Ans:-  Coariance is show variable differ but correlation is show variable relation.
       this is the basic difference.

'''

'''Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.

Ans:-outliers affected when calculating mean .

'''
